# %% [markdown]
# <a href="https://colab.research.google.com/github/danii088/Computational-Physics/blob/master/Bell_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 

groceries = pd.read_excel('superstore_dataset.xls')

# %%
groceries
# Out:
#        Row ID         Order ID  ... Shipping Cost Order Priority
# 0       42433     AG-2011-2040  ...         35.46         Medium
# 1       22253    IN-2011-47883  ...          9.72         Medium
# 2       48883     HU-2011-1220  ...          8.17           High
# 3       11731  IT-2011-3647632  ...          4.82           High
# 4       22255    IN-2011-47883  ...          4.70         Medium
# ...       ...              ...  ...           ...            ...
# 51285   32593   CA-2014-115427  ...          0.89         Medium
# 51286   47594     MO-2014-2560  ...          0.49         Medium
# 51287    8857   MX-2014-110527  ...          0.35         Medium
# 51288    6852   MX-2014-114783  ...          0.20         Medium
# 51289   36388   CA-2014-156720  ...          0.17         Medium
#
# [51290 rows x 24 columns]

# %%
corr_table = groceries.corr()
corr_table
# Out:
#                  Row ID  Postal Code  ...    Profit  Shipping Cost
# Row ID         1.000000     0.009671  ... -0.019037      -0.039078
# Postal Code    0.009671     1.000000  ... -0.029961      -0.025449
# Sales         -0.043889    -0.023854  ...  0.484918       0.768073
# Quantity      -0.173483     0.012761  ...  0.104365       0.272649
# Discount       0.087594     0.058443  ... -0.316490      -0.079056
# Profit        -0.019037    -0.029961  ...  1.000000       0.354441
# Shipping Cost -0.039078    -0.025449  ...  0.354441       1.000000
#
# [7 rows x 7 columns]
